# %%
#import all the required libraries
import pandas as pd
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome("C:\\Users\\Preeti kumari\\chromedriver.exe")
# Out:
# <ipython-input-193-56a44a4849dd>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("C:\\Users\\Preeti kumari\\chromedriver.exe")

# %%
url="https://trak.in/india-startup-funding-investment-2015/"

# %%
driver.get(url)

# %%
datee=[]

# %%
date=driver.find_elements_by_xpath("//td[@class='column-2']")
for i in date:
    if i.text is None :
        datee.append("--") 
    else:
        datee.append(i.text)
    
datee[34:64]
# Out:
# ['08/09/2020',
#  '12/09/2020',
#  '09/09/2020',
#  '02/09/2020',
#  '09/09/2020',
#  '07/09/2020',
#  '07/09/2020',
#  '31/08/2020',
#  '31/08/2020',
#  '03/09/2020',
#  '15/08/2020',
#  '13/08/2020',
#  '13/08/2020',
#  '04/08/2020',
#  '11/08/2020',
#  '12/08/2020',
#  '14/08/2020',
#  '10/08/2020',
#  '07/08/2020',
#  '13/08/2020',
#  '15/07/2020',
#  '16/07/2020',
#  '16/07/2020',
#  '14/07/2020',
#  '13/07/2020',
#  '09/07/2020',
#  '10/07/2020',
#  '15/07/2020',
#  '14/07/2020',
#  '13/07/2020']

# %%
date_=pd.DataFrame(datee)

# %%
import re

# %%
date_.loc[date_[0].str.contains('/07/2020',flags=re.I,regex=True)]
# Out:
#              0
# 54  15/07/2020
# 55  16/07/2020
# 56  16/07/2020
# 57  14/07/2020
# 58  13/07/2020
# 59  09/07/2020
# 60  10/07/2020
# 61  15/07/2020
# 62  14/07/2020
# 63  13/07/2020

# %%
d2=date_.loc[date_[0].str.contains('/08/2020',flags=re.I,regex=True)]
d2
# Out:
#              0
# 41  31/08/2020
# 42  31/08/2020
# 44  15/08/2020
# 45  13/08/2020
# 46  13/08/2020
# 47  04/08/2020
# 48  11/08/2020
# 49  12/08/2020
# 50  14/08/2020
# 51  10/08/2020
# 52  07/08/2020
# 53  13/08/2020

# %%
d3=date_.loc[date_[0].str.contains('/09/2020',flags=re.I,regex=True)]
d3
# Out:
#              0
# 34  08/09/2020
# 35  12/09/2020
# 36  09/09/2020
# 37  02/09/2020
# 38  09/09/2020
# 39  07/09/2020
# 40  07/09/2020
# 43  03/09/2020

# %%
#from above we can see range for the month of july,aug and sept is frm 34 to 64 so now we will extract all the columns and then just extract from the range 34-64

# %%
co=[]

# %%
date=driver.find_elements_by_xpath("//td[@class='column-2']")
for i in date:
    if i.text is None :
        co.append("--") 
    else:
        co.append(i.text)
# Out:
# C:\Users\Preeti kumari\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:470: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
co=co[34:64]

# %%
co2=[]
co3=[]
co4=[]
co5=[]
co6=[]
co7=[]
co8=[]

# %%
date=driver.find_elements_by_xpath("//td[@class='column-3']")
for i in date:
    if i.text is None :
        co2.append("--") 
    else:
        co2.append(i.text)

# %%
date=driver.find_elements_by_xpath("//td[@class='column-4']")
for i in date:
    if i.text is None :
        co3.append("--") 
    else:
        co3.append(i.text)

# %%
date=driver.find_elements_by_xpath("//td[@class='column-5']")
for i in date:
    if i.text is None :
        co4.append("--") 
    else:
        co4.append(i.text)

# %%
date=driver.find_elements_by_xpath("//td[@class='column-6']")
for i in date:
    if i.text is None :
        co5.append("--") 
    else:
        co5.append(i.text)

# %%
date=driver.find_elements_by_xpath("//td[@class='column-7']")
for i in date:
    if i.text is None :
        co6.append("--") 
    else:
        co6.append(i.text)

# %%
date=driver.find_elements_by_xpath("//td[@class='column-8']")
for i in date:
    if i.text is None :
        co7.append("--") 
    else:
        co7.append(i.text)

# %%
date=driver.find_elements_by_xpath("//td[@class='column-9']")
for i in date:
    if i.text is None :
        co8.append("---") 
    else:
        co8.append(i.text)

# %%
co2=co2[34:64]
co3=co3[34:64]
co4=co4[34:64]
co5=co5[34:64]
co6=co6[34:64]
co7=co7[34:64]
co8=co8[34:64]

#now we will extract all the columns and then just extract from the range 34-64

# %%
data=list(zip(co,co2,co3,co4,co5,co6,co7,co8))

# %%
df=pd.DataFrame(data,columns=["Date","Startup_name","Industry/Vertical","Sub-Vertical","City","Investor's Name","Investment_type","Amount(In USD)"])

# %%
df
# Out:
#           Date               Startup_name  \
# 0   08/09/2020                     Byju’s
# 1   12/09/2020                  mCaffeine
# 2   09/09/2020                     Qshala
# 3   02/09/2020                      Winzo
# 4   09/09/2020                Hippo Video
# 5   07/09/2020                    Melorra
# 6   07/09/2020                        1mg
# 7   31/08/2020                      mfine
# 8   31/08/2020                       Apna
# 9   03/09/2020                    Railofy
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  15/07/2020                   Flipkart
# ...
